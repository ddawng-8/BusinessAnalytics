# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/minknhom/dataset/main/FB.csv', index_col='Date')

start_date = '2010-01-01'
end_date = '2022-12-31'

df = df[(df.index >= start_date) & (df.index <= end_date)]

df1 = df.reset_index()['Close']

df1.plot()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %% [markdown]
# # Mục mới

# %%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size + test_size]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 13s 236ms/step - loss: 0.0136
# Epoch 2/100
# 30/30 [==============================] - 6s 195ms/step - loss: 7.1549e-04
# Epoch 3/100
# 30/30 [==============================] - 7s 238ms/step - loss: 3.7961e-04
# Epoch 4/100
# 30/30 [==============================] - 6s 192ms/step - loss: 3.9122e-04
# Epoch 5/100
# 30/30 [==============================] - 7s 241ms/step - loss: 3.6558e-04
# Epoch 6/100
# 30/30 [==============================] - 6s 196ms/step - loss: 3.6251e-04
# Epoch 7/100
# 30/30 [==============================] - 7s 241ms/step - loss: 3.5026e-04
# Epoch 8/100
# 30/30 [==============================] - 6s 202ms/step - loss: 3.4992e-04
# Epoch 9/100
# 30/30 [==============================] - 7s 243ms/step - loss: 3.4179e-04
# Epoch 10/100
# 30/30 [==============================] - 6s 201ms/step - loss: 3.2690e-04
# Epoch 11/100
# 30/30 [==============================] - 7s 240ms/step - loss: 3.3849e-04
# Epoch 12/100
# 30/30 [==============================] - 6s 197ms/step - loss: 3.3665e-04
# Epoch 13/100
# 30/30 [==============================] - 7s 241ms/step - loss: 2.8321e-04
# Epoch 14/100
# 30/30 [==============================] - 6s 195ms/step - loss: 2.7289e-04
# Epoch 15/100
# 30/30 [==============================] - 7s 238ms/step - loss: 2.6999e-04
# Epoch 16/100
# 30/30 [==============================] - 6s 194ms/step - loss: 2.7424e-04
# Epoch 17/100
# 30/30 [==============================] - 7s 238ms/step - loss: 2.7092e-04
# Epoch 18/100
# 30/30 [==============================] - 6s 197ms/step - loss: 2.6379e-04
# Epoch 19/100
# 30/30 [==============================] - 7s 237ms/step - loss: 2.7541e-04
# Epoch 20/100
# 30/30 [==============================] - 6s 194ms/step - loss: 2.5157e-04
# Epoch 21/100
# 30/30 [==============================] - 7s 237ms/step - loss: 2.3862e-04
# Epoch 22/100
# 30/30 [==============================] - 6s 191ms/step - loss: 2.3473e-04
# Epoch 23/100
# 30/30 [==============================] - 7s 235ms/step - loss: 2.3879e-04
# Epoch 24/100
# 30/30 [==============================] - 6s 194ms/step - loss: 2.4763e-04
# Epoch 25/100
# 30/30 [==============================] - 7s 239ms/step - loss: 2.4492e-04
# Epoch 26/100
# 30/30 [==============================] - 6s 195ms/step - loss: 2.3226e-04
# Epoch 27/100
# 30/30 [==============================] - 7s 234ms/step - loss: 2.2122e-04
# Epoch 28/100
# 30/30 [==============================] - 6s 192ms/step - loss: 2.1782e-04
# Epoch 29/100
# 30/30 [==============================] - 7s 238ms/step - loss: 2.2169e-04
# Epoch 30/100
# 30/30 [==============================] - 6s 192ms/step - loss: 2.2249e-04
# Epoch 31/100
# 30/30 [==============================] - 7s 236ms/step - loss: 2.0459e-04
# Epoch 32/100
# 30/30 [==============================] - 6s 195ms/step - loss: 2.1297e-04
# Epoch 33/100
# 30/30 [==============================] - 7s 236ms/step - loss: 2.1180e-04
# Epoch 34/100
# 30/30 [==============================] - 6s 194ms/step - loss: 2.0679e-04
# Epoch 35/100
# 30/30 [==============================] - 7s 233ms/step - loss: 1.9488e-04
# Epoch 36/100
# 30/30 [==============================] - 6s 193ms/step - loss: 1.8557e-04
# Epoch 37/100
# 30/30 [==============================] - 7s 230ms/step - loss: 1.9643e-04
# Epoch 38/100
# 30/30 [==============================] - 6s 196ms/step - loss: 1.9834e-04
# Epoch 39/100
# 30/30 [==============================] - 7s 231ms/step - loss: 2.2389e-04
# Epoch 40/100
# 30/30 [==============================] - 6s 205ms/step - loss: 2.1406e-04
# Epoch 41/100
# 30/30 [==============================] - 7s 225ms/step - loss: 1.7856e-04
# Epoch 42/100
# 30/30 [==============================] - 6s 204ms/step - loss: 1.7808e-04
# Epoch 43/100
# 30/30 [==============================] - 7s 225ms/step - loss: 1.7930e-04
# Epoch 44/100
# 30/30 [==============================] - 6s 201ms/step - loss: 1.7520e-04
# Epoch 45/100
# 30/30 [==============================] - 7s 222ms/step - loss: 1.7321e-04
# Epoch 46/100
# 30/30 [==============================] - 6s 204ms/step - loss: 2.0745e-04
# Epoch 47/100
# 30/30 [==============================] - 6s 215ms/step - loss: 1.7134e-04
# Epoch 48/100
# 30/30 [==============================] - 7s 214ms/step - loss: 1.6470e-04
# Epoch 49/100
# 30/30 [==============================] - 6s 214ms/step - loss: 1.5556e-04
# Epoch 50/100
# 30/30 [==============================] - 6s 212ms/step - loss: 1.5630e-04
# Epoch 51/100
# 30/30 [==============================] - 6s 212ms/step - loss: 1.5053e-04
# Epoch 52/100
# 30/30 [==============================] - 7s 220ms/step - loss: 1.5426e-04
# Epoch 53/100
# 30/30 [==============================] - 6s 212ms/step - loss: 1.4528e-04
# Epoch 54/100
# 30/30 [==============================] - 7s 219ms/step - loss: 1.5511e-04
# Epoch 55/100
# 30/30 [==============================] - 9s 305ms/step - loss: 1.4721e-04
# Epoch 56/100
# 30/30 [==============================] - 6s 197ms/step - loss: 1.3590e-04
# Epoch 57/100
# 30/30 [==============================] - 7s 242ms/step - loss: 1.2956e-04
# Epoch 58/100
# 30/30 [==============================] - 6s 201ms/step - loss: 1.2846e-04
# Epoch 59/100
# 30/30 [==============================] - 7s 243ms/step - loss: 1.4511e-04
# Epoch 60/100
# 30/30 [==============================] - 7s 245ms/step - loss: 1.5890e-04
# Epoch 61/100
# 30/30 [==============================] - 7s 238ms/step - loss: 1.2619e-04
# Epoch 62/100
# 30/30 [==============================] - 6s 194ms/step - loss: 1.2502e-04
# Epoch 63/100
# 30/30 [==============================] - 7s 237ms/step - loss: 1.2510e-04
# Epoch 64/100
# 30/30 [==============================] - 6s 197ms/step - loss: 1.2045e-04
# Epoch 65/100
# 30/30 [==============================] - 7s 237ms/step - loss: 1.3139e-04
# Epoch 66/100
# 30/30 [==============================] - 6s 196ms/step - loss: 1.2464e-04
# Epoch 67/100
# 30/30 [==============================] - 7s 239ms/step - loss: 1.1582e-04
# Epoch 68/100
# 30/30 [==============================] - 6s 194ms/step - loss: 1.4181e-04
# Epoch 69/100
# 30/30 [==============================] - 7s 240ms/step - loss: 1.6340e-04
# Epoch 70/100
# 30/30 [==============================] - 6s 195ms/step - loss: 1.1714e-04
# Epoch 71/100
# 30/30 [==============================] - 7s 240ms/step - loss: 1.1642e-04
# Epoch 72/100
# 30/30 [==============================] - 6s 196ms/step - loss: 1.1558e-04
# Epoch 73/100
# 30/30 [==============================] - 7s 240ms/step - loss: 1.1027e-04
# Epoch 74/100
# 30/30 [==============================] - 6s 195ms/step - loss: 1.0063e-04
# Epoch 75/100
# 30/30 [==============================] - 7s 241ms/step - loss: 1.0573e-04
# Epoch 76/100
# 30/30 [==============================] - 6s 198ms/step - loss: 1.1614e-04
# Epoch 77/100
# 30/30 [==============================] - 7s 238ms/step - loss: 9.5059e-05
# Epoch 78/100
# 30/30 [==============================] - 6s 197ms/step - loss: 1.0938e-04
# Epoch 79/100
# 30/30 [==============================] - 7s 236ms/step - loss: 8.9243e-05
# Epoch 80/100
# 30/30 [==============================] - 6s 191ms/step - loss: 9.0119e-05
# Epoch 81/100
# 30/30 [==============================] - 7s 236ms/step - loss: 9.6173e-05
# Epoch 82/100
# 30/30 [==============================] - 6s 191ms/step - loss: 1.1599e-04
# Epoch 83/100
# 30/30 [==============================] - 7s 235ms/step - loss: 9.8290e-05
# Epoch 84/100
# 30/30 [==============================] - 6s 194ms/step - loss: 1.2212e-04
# Epoch 85/100
# 30/30 [==============================] - 7s 235ms/step - loss: 9.9518e-05
# Epoch 86/100
# 30/30 [==============================] - 6s 195ms/step - loss: 9.8557e-05
# Epoch 87/100
# 30/30 [==============================] - 7s 241ms/step - loss: 9.3879e-05
# Epoch 88/100
# 30/30 [==============================] - 6s 194ms/step - loss: 1.0808e-04
# Epoch 89/100
# 30/30 [==============================] - 7s 237ms/step - loss: 8.9319e-05
# Epoch 90/100
# 30/30 [==============================] - 6s 193ms/step - loss: 1.1126e-04
# Epoch 91/100
# 30/30 [==============================] - 7s 228ms/step - loss: 1.1853e-04
# Epoch 92/100
# 30/30 [==============================] - 6s 197ms/step - loss: 9.8009e-05
# Epoch 93/100
# 30/30 [==============================] - 7s 225ms/step - loss: 9.2654e-05
# Epoch 94/100
# 30/30 [==============================] - 6s 202ms/step - loss: 8.0462e-05
# Epoch 95/100
# 30/30 [==============================] - 7s 223ms/step - loss: 8.1528e-05
# Epoch 96/100
# 30/30 [==============================] - 6s 205ms/step - loss: 1.0597e-04
# Epoch 97/100
# 30/30 [==============================] - 7s 220ms/step - loss: 8.2775e-05
# Epoch 98/100
# 30/30 [==============================] - 6s 210ms/step - loss: 8.6866e-05
# Epoch 99/100
# 30/30 [==============================] - 6s 211ms/step - loss: 7.9069e-05
# Epoch 100/100
# 30/30 [==============================] - 7s 215ms/step - loss: 7.6963e-05

# %%
train_predict=model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 59/59 [==============================] - 5s 48ms/step
# 13/13 [==============================] - 1s 45ms/step

# %%
# Tính toán sai số tuyệt đối và chuẩn hóa thành phần trăm
errors = np.abs((y_test- y_pred) / y_test) * 100

# Tính giá trị MAPE
mape = np.mean(errors)
print('Testing MAPE:', mape)
from sklearn.metrics import mean_absolute_error

# y_true là mảng chứa các giá trị thực tế
# y_pred là mảng chứa các giá trị dự đoán
mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', mae)
# Out:
# Testing MAPE: 18.43620931520584
# Testing MAE: 0.03098859210845028

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)

# %%
train_size = int(0.8 * len(df1))
test_size1 = len(df1) - train_size -101

train_data = df1[:train_size]
test_data1 = df1[train_size:train_size+test_size1]

# %%
test_data1=scaler.inverse_transform(test_data1)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - test_data1)**2))
print('Testing RMSE:', test_rmse)
# Out:
# Testing RMSE: 59.081941218259004

# %%
import matplotlib.pyplot as plt

# %%
x_input = test_data[-100:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1
future_predictions = scaler.inverse_transform(lst_output)

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()

# %% [markdown]
# # Mục mới
