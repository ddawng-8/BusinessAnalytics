# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/minknhom/dataset/main/FB.csv', index_col='Date')

start_date = '2010-01-01'
end_date = '2022-12-31'

df = df[(df.index >= start_date) & (df.index <= end_date)]

df1 = df.reset_index()['Close']

df1.plot()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %% [markdown]
# # Mục mới

# %%
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size + test_size]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 13s 198ms/step - loss: 0.0147
# Epoch 2/100
# 26/26 [==============================] - 6s 249ms/step - loss: 7.6340e-04
# Epoch 3/100
# 26/26 [==============================] - 5s 194ms/step - loss: 2.9854e-04
# Epoch 4/100
# 26/26 [==============================] - 6s 244ms/step - loss: 2.6156e-04
# Epoch 5/100
# 26/26 [==============================] - 5s 201ms/step - loss: 2.6152e-04
# Epoch 6/100
# 26/26 [==============================] - 6s 228ms/step - loss: 2.5149e-04
# Epoch 7/100
# 26/26 [==============================] - 6s 214ms/step - loss: 2.4362e-04
# Epoch 8/100
# 26/26 [==============================] - 5s 191ms/step - loss: 2.6849e-04
# Epoch 9/100
# 26/26 [==============================] - 6s 241ms/step - loss: 2.4607e-04
# Epoch 10/100
# 26/26 [==============================] - 5s 197ms/step - loss: 2.3830e-04
# Epoch 11/100
# 26/26 [==============================] - 6s 243ms/step - loss: 2.3151e-04
# Epoch 12/100
# 26/26 [==============================] - 5s 191ms/step - loss: 2.3336e-04
# Epoch 13/100
# 26/26 [==============================] - 5s 207ms/step - loss: 2.2907e-04
# Epoch 14/100
# 26/26 [==============================] - 6s 218ms/step - loss: 2.2582e-04
# Epoch 15/100
# 26/26 [==============================] - 7s 268ms/step - loss: 2.2169e-04
# Epoch 16/100
# 26/26 [==============================] - 6s 221ms/step - loss: 2.1236e-04
# Epoch 17/100
# 26/26 [==============================] - 5s 190ms/step - loss: 2.1204e-04
# Epoch 18/100
# 26/26 [==============================] - 6s 239ms/step - loss: 2.0470e-04
# Epoch 19/100
# 26/26 [==============================] - 5s 189ms/step - loss: 2.2000e-04
# Epoch 20/100
# 26/26 [==============================] - 6s 223ms/step - loss: 2.0551e-04
# Epoch 21/100
# 26/26 [==============================] - 5s 198ms/step - loss: 2.0088e-04
# Epoch 22/100
# 26/26 [==============================] - 5s 189ms/step - loss: 1.9379e-04
# Epoch 23/100
# 26/26 [==============================] - 6s 240ms/step - loss: 2.0995e-04
# Epoch 24/100
# 26/26 [==============================] - 8s 293ms/step - loss: 1.9863e-04
# Epoch 25/100
# 26/26 [==============================] - 8s 283ms/step - loss: 2.0063e-04
# Epoch 26/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.8338e-04
# Epoch 27/100
# 26/26 [==============================] - 6s 244ms/step - loss: 2.1082e-04
# Epoch 28/100
# 26/26 [==============================] - 5s 192ms/step - loss: 2.1467e-04
# Epoch 29/100
# 26/26 [==============================] - 6s 242ms/step - loss: 1.9388e-04
# Epoch 30/100
# 26/26 [==============================] - 5s 191ms/step - loss: 2.1035e-04
# Epoch 31/100
# 26/26 [==============================] - 5s 206ms/step - loss: 1.7854e-04
# Epoch 32/100
# 26/26 [==============================] - 6s 223ms/step - loss: 1.7042e-04
# Epoch 33/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.8433e-04
# Epoch 34/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.8483e-04
# Epoch 35/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.8390e-04
# Epoch 36/100
# 26/26 [==============================] - 6s 236ms/step - loss: 1.6854e-04
# Epoch 37/100
# 26/26 [==============================] - 5s 190ms/step - loss: 1.8086e-04
# Epoch 38/100
# 26/26 [==============================] - 5s 194ms/step - loss: 1.8976e-04
# Epoch 39/100
# 26/26 [==============================] - 6s 239ms/step - loss: 1.7302e-04
# Epoch 40/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.9266e-04
# Epoch 41/100
# 26/26 [==============================] - 6s 243ms/step - loss: 2.0579e-04
# Epoch 42/100
# 26/26 [==============================] - 5s 198ms/step - loss: 1.6517e-04
# Epoch 43/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.6330e-04
# Epoch 44/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.5489e-04
# Epoch 45/100
# 26/26 [==============================] - 5s 193ms/step - loss: 1.5689e-04
# Epoch 46/100
# 26/26 [==============================] - 6s 241ms/step - loss: 1.5289e-04
# Epoch 47/100
# 26/26 [==============================] - 5s 194ms/step - loss: 1.7213e-04
# Epoch 48/100
# 26/26 [==============================] - 6s 242ms/step - loss: 1.6529e-04
# Epoch 49/100
# 26/26 [==============================] - 5s 193ms/step - loss: 1.5634e-04
# Epoch 50/100
# 26/26 [==============================] - 6s 221ms/step - loss: 1.5225e-04
# Epoch 51/100
# 26/26 [==============================] - 5s 201ms/step - loss: 1.5117e-04
# Epoch 52/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.4441e-04
# Epoch 53/100
# 26/26 [==============================] - 6s 241ms/step - loss: 1.5626e-04
# Epoch 54/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.4619e-04
# Epoch 55/100
# 26/26 [==============================] - 6s 242ms/step - loss: 1.4123e-04
# Epoch 56/100
# 26/26 [==============================] - 5s 193ms/step - loss: 1.6661e-04
# Epoch 57/100
# 26/26 [==============================] - 5s 210ms/step - loss: 1.5881e-04
# Epoch 58/100
# 26/26 [==============================] - 6s 225ms/step - loss: 1.3964e-04
# Epoch 59/100
# 26/26 [==============================] - 5s 193ms/step - loss: 1.4645e-04
# Epoch 60/100
# 26/26 [==============================] - 6s 241ms/step - loss: 1.6733e-04
# Epoch 61/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.3696e-04
# Epoch 62/100
# 26/26 [==============================] - 6s 240ms/step - loss: 1.3322e-04
# Epoch 63/100
# 26/26 [==============================] - 5s 191ms/step - loss: 1.3764e-04
# Epoch 64/100
# 26/26 [==============================] - 5s 195ms/step - loss: 1.4205e-04
# Epoch 65/100
# 26/26 [==============================] - 6s 234ms/step - loss: 1.4354e-04
# Epoch 66/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.2754e-04
# Epoch 67/100
# 26/26 [==============================] - 6s 242ms/step - loss: 1.2730e-04
# Epoch 68/100
# 26/26 [==============================] - 5s 188ms/step - loss: 1.5306e-04
# Epoch 69/100
# 26/26 [==============================] - 6s 229ms/step - loss: 1.2569e-04
# Epoch 70/100
# 26/26 [==============================] - 5s 197ms/step - loss: 1.4228e-04
# Epoch 71/100
# 26/26 [==============================] - 5s 190ms/step - loss: 1.2028e-04
# Epoch 72/100
# 26/26 [==============================] - 6s 241ms/step - loss: 1.1502e-04
# Epoch 73/100
# 26/26 [==============================] - 5s 188ms/step - loss: 1.1975e-04
# Epoch 74/100
# 26/26 [==============================] - 6s 240ms/step - loss: 1.4787e-04
# Epoch 75/100
# 26/26 [==============================] - 5s 190ms/step - loss: 1.2299e-04
# Epoch 76/100
# 26/26 [==============================] - 5s 202ms/step - loss: 1.0452e-04
# Epoch 77/100
# 26/26 [==============================] - 6s 222ms/step - loss: 1.1284e-04
# Epoch 78/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.1379e-04
# Epoch 79/100
# 26/26 [==============================] - 6s 239ms/step - loss: 1.0170e-04
# Epoch 80/100
# 26/26 [==============================] - 5s 190ms/step - loss: 1.0681e-04
# Epoch 81/100
# 26/26 [==============================] - 6s 231ms/step - loss: 1.3578e-04
# Epoch 82/100
# 26/26 [==============================] - 5s 194ms/step - loss: 1.0935e-04
# Epoch 83/100
# 26/26 [==============================] - 5s 190ms/step - loss: 9.5389e-05
# Epoch 84/100
# 26/26 [==============================] - 6s 240ms/step - loss: 1.0882e-04
# Epoch 85/100
# 26/26 [==============================] - 5s 194ms/step - loss: 1.0597e-04
# Epoch 86/100
# 26/26 [==============================] - 6s 241ms/step - loss: 9.5777e-05
# Epoch 87/100
# 26/26 [==============================] - 5s 190ms/step - loss: 9.4047e-05
# Epoch 88/100
# 26/26 [==============================] - 5s 207ms/step - loss: 9.4113e-05
# Epoch 89/100
# 26/26 [==============================] - 6s 217ms/step - loss: 8.7612e-05
# Epoch 90/100
# 26/26 [==============================] - 5s 193ms/step - loss: 8.4553e-05
# Epoch 91/100
# 26/26 [==============================] - 6s 242ms/step - loss: 9.3176e-05
# Epoch 92/100
# 26/26 [==============================] - 5s 190ms/step - loss: 8.5054e-05
# Epoch 93/100
# 26/26 [==============================] - 6s 237ms/step - loss: 8.2142e-05
# Epoch 94/100
# 26/26 [==============================] - 5s 187ms/step - loss: 1.0080e-04
# Epoch 95/100
# 26/26 [==============================] - 5s 188ms/step - loss: 9.4374e-05
# Epoch 96/100
# 26/26 [==============================] - 6s 240ms/step - loss: 9.4731e-05
# Epoch 97/100
# 26/26 [==============================] - 5s 189ms/step - loss: 7.9992e-05
# Epoch 98/100
# 26/26 [==============================] - 6s 238ms/step - loss: 7.8848e-05
# Epoch 99/100
# 26/26 [==============================] - 5s 190ms/step - loss: 1.2815e-04
# Epoch 100/100
# 26/26 [==============================] - 6s 215ms/step - loss: 8.2173e-05

# %%
train_predict=model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 52/52 [==============================] - 4s 43ms/step
# 21/21 [==============================] - 1s 43ms/step

# %%
# Tính toán sai số tuyệt đối và chuẩn hóa thành phần trăm
errors = np.abs((y_test- y_pred) / y_test) * 100

# Tính giá trị MAPE
mape = np.mean(errors)
print('Testing MAPE:', mape)
from sklearn.metrics import mean_absolute_error

# y_true là mảng chứa các giá trị thực tế
# y_pred là mảng chứa các giá trị dự đoán
mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', mae)
# Out:
# Testing MAPE: 26.499912426362222
# Testing MAE: 0.05513539767819246

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)

# %%
train_size = int(0.7 * len(df1))
test_size1 = len(df1) - train_size -101

train_data = df1[:train_size]
test_data1 = df1[train_size:train_size+test_size1]

# %%
test_data1=scaler.inverse_transform(test_data1)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - test_data1)**2))
print('Testing RMSE:', test_rmse)
# Out:
# Testing RMSE: 48.733897935856994

# %%
import matplotlib.pyplot as plt

# %%
x_input = test_data[-100:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1
future_predictions = scaler.inverse_transform(lst_output)

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()

# %% [markdown]
# # Mục mới
